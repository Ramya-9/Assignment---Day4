# %%
RequiredAltitude= int(input("Enter the Altitude of the plane Now - "))
if RequiredAltitude < 1000:
  print("Safe to land ! , Please Land the plane")
elif RequiredAltitude > 1000 & RequiredAltitude  < 5000:
  print("Please come down to 1000ft !")
else:
  print("Turn around and try later ! ")
# Out:
# Enter the Altitude of the plane Now - 2750
# Please come down to 1000ft !
